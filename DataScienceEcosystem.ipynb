# %% [markdown]
# Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# ordered List
# Python
# R Studio
# SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# ordered list NumPy · Matplotlib · Pandas · SciPy

# %% [markdown]
# Data Science Tools
# RStudio, Apache Spark, TensorFlow, Apache Hadoop, RapidMiner

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python
# result  = a + b
# print(f"Addition: {a} + {b} = {result}")

# %%
result=(3*4)+5
print(f"{result}")
# Out:
# 17

# %%
mintues=200
hours=200/60
print(f"{hours}")
# Out:
# 3.3333333333333335

# %% [markdown]
# Objectives:
# Descriptive analytics: Summarize and interpret historical data to understand past performance.
# Predictive analytics: Forecast future results based on historical data to anticipate trends and potential issues.
# Prescriptive analytics: Provide recommendations and suggest actions to optimize outcomes based on data analysis.
# Problem-solving: Use a variety of techniques to solve complex problems across different fields, such as predicting patient risks or suggesting personalized treatments

# %% [markdown]
# Author: Syed Ali Abid
